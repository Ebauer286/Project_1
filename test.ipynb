# %%
import pandas as pd

# %%
df = pd.read_csv('billboard_hot_100_csvs/2024_bb_hot_100.csv')

df1 = df.sort_values(by = 'weeks on chart', ascending = False)
df1.head(20)
# Out:
#       rank                            title         artist  \
# 1618    19                           Snooze            SZA
# 1519    20                           Snooze            SZA
# 1416    17                           Snooze            SZA
# 1322    23                           Snooze            SZA
# 1213    14                           Snooze            SZA
# 1        2  All I Want For Christmas Is You   Mariah Carey
# 1110    11                           Snooze            SZA
# 1007     8                           Snooze            SZA
# 908      9                           Snooze            SZA
# 805      6                           Snooze            SZA
# 4205     6                     Lose Control    Teddy Swims
# 706      7                           Snooze            SZA
# 4107     8                     Lose Control    Teddy Swims
# 1215    16                       Last Night  Morgan Wallen
# 604      5                           Snooze            SZA
# ...
